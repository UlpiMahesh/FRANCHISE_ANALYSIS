# %%
import os
import hashlib
import re
import requests as r
from bs4 import BeautifulSoup as bs
from concurrent.futures import ThreadPoolExecutor as te,as_completed 
from concurrent.futures import ThreadPoolExecutor as te
from urllib.parse import urlparse

# Create folder if it doesn't exist in current working directory
CACHE_DIR = "cached_pages"
os.makedirs(CACHE_DIR, exist_ok=True)

def sanitize_filename(url):
    """
    Create a readable filename from a URL (e.g., franchisebazar.com_industry_food.html)
    """
    parsed = urlparse(url)
    domain = parsed.netloc.replace('.', '_')
    path = parsed.path.strip('/').replace('/', '_')
    filename = f"{domain}_{path}.html"
    # Remove illegal characters (Windows safe)
    filename = re.sub(r'[<>:"/\\|?*]', '', filename)
    return filename

def cache_url(url, refresh=False):
    """
    Checks if the URL has been cached. If yes and refresh=False, load from disk.
    If not, fetch and save to disk.
    """
    filename = sanitize_filename(url)
    filepath = os.path.join(CACHE_DIR, filename)

    if os.path.exists(filepath) and not refresh:
        with open(filepath, 'r', encoding='utf-8') as file:
            print(f"[CACHE] Using cached: {filepath}")
            return file.read()

    print(f"[LIVE] Fetching and caching: {url}")
    response = r.get(url, timeout=10)
    with open(filepath, 'w', encoding='utf-8') as file:
        file.write(response.text)
    return response.text

# %%
url = 'https://www.franchisebazar.com/'
response = cache_url(url)

soup = bs(response,'html.parser')
cards = soup.find("ul", class_="franchise-container open")

industry_links = cards.find_all('li')

industries = {}
for li in industry_links:
    a_tag = li.find('a')
    if a_tag:
        link = a_tag['href']
        industry = a_tag.get_text(strip=True)
        industries[industry]=url+link
print(industries)
# Out:
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_.html
# {'Agents, Dealers & Distributors': 'https://www.franchisebazar.com//industry/agents-dealers-distributors', 'Automotive Franchise': 'https://www.franchisebazar.com//industry/automotive-franchise', 'Beauty Franchise': 'https://www.franchisebazar.com//industry/beauty-franchise', 'Beverage Franchise': 'https://www.franchisebazar.com//industry/beverage-franchise', 'Business Services Franchise': 'https://www.franchisebazar.com//industry/business-services-franchise', 'Cleaning Franchise': 'https://www.franchisebazar.com//industry/cleaning-franchise-opportunities', 'Clothing Franchise': 'https://www.franchisebazar.com//industry/clothing-franchise-opportunities', 'Computer & Internet Franchise': 'https://www.franchisebazar.com//industry/computer-internet-franchise', 'Construction Franchise': 'https://www.franchisebazar.com//industry/construction-related-franchise', 'Consultancy Franchise': 'https://www.franchisebazar.com//industry/consultancy-franchise-opportunities', 'Education Franchise': 'https://www.franchisebazar.com//industry/education-franchise-opportunities', 'Entertainment & Leisure': 'https://www.franchisebazar.com//industry/entertainment-leisure-franchise', 'Financial Service Franchise': 'https://www.franchisebazar.com//industry/financial-service-franchise', 'Fitness Franchise': 'https://www.franchisebazar.com//industry/fitness-franchise', 'Food Franchise': 'https://www.franchisebazar.com//industry/food-franchise-opportunities', 'Health Care Franchise': 'https://www.franchisebazar.com//industry/health-care-franchise', 'Hotel Franchise': 'https://www.franchisebazar.com//industry/hotel-franchise-opportunities', 'Icecream Franchise': 'https://www.franchisebazar.com//industry/icecream-franchise', 'Jewellery Franchise': 'https://www.franchisebazar.com//industry/jewellery-franchise-opportunities', 'Logistics Franchise': 'https://www.franchisebazar.com//industry/logistics-franchise', 'Manufacturing Franchise': 'https://www.franchisebazar.com//industry/manufacturing-franchise-opportunities', 'Pet Franchise': 'https://www.franchisebazar.com//industry/pet-franchise', 'Preschool Franchise': 'https://www.franchisebazar.com//industry/preschool-franchise', 'Real Estate Franchise': 'https://www.franchisebazar.com//industry/real-estate-franchise', 'Restaurant Franchise': 'https://www.franchisebazar.com//industry/restaurant-franchise', 'Retail Franchise': 'https://www.franchisebazar.com//industry/retail-franchise', 'Sports Franchise': 'https://www.franchisebazar.com//industry/sports-franchise-opportunities', 'Travel Franchise': 'https://www.franchisebazar.com//industry/travel-franchise-opportunities', 'Work From Home': 'https://www.franchisebazar.com//industry/work-from-home'}

# %%
def get_industries(name,link):
    try:
        industry_type=name
        url = link
        response = cache_url(url)
        soup = bs(response,'html.parser')
        cards = soup.find('div',class_="row karya")
        #if no output from above code then empty dictionary will be returned
        if not cards:
            return (name,{})
            
        industry_link = cards.find_all('div',class_='investor-card-wrapper')
        
        franchise_details = {}
        for div in industry_link:
            link_tag=div.find('a')
            location_tag=div.find('div',class_='col-lg-8 col-xs-8 text-right')
            name_tag = div.find('div',class_='main-title')
            
            if name_tag and link_tag and location_tag:
                franchise_name = name_tag.get_text(strip=True)
                link = link_tag['href']
                city = location_tag.get_text(strip=True)
                franchise_details[franchise_name]=[url+link,city]
        return industry_type,franchise_details
        
    except Exception as e:
        return (name,{"error":str(e)})
            
industry_franchies = []
with te(max_workers=10) as executor:
    futures=[executor.submit(get_industries,name,link) for name,link in industries.items()]
for future in as_completed(futures):
    industry_franchies.append((future.result()))
    
print(industry_franchies)
# Out:
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_agents-dealers-distributors.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_automotive-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_beauty-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_beverage-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_business-services-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_clothing-franchise-opportunities.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_cleaning-franchise-opportunities.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_construction-related-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_computer-internet-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_consultancy-franchise-opportunities.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_education-franchise-opportunities.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_entertainment-leisure-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_financial-service-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_fitness-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_food-franchise-opportunities.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_health-care-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_icecream-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_hotel-franchise-opportunities.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_jewellery-franchise-opportunities.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_logistics-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_manufacturing-franchise-opportunities.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_pet-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_preschool-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_real-estate-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_restaurant-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_retail-franchise.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_sports-franchise-opportunities.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_travel-franchise-opportunities.html
# [CACHE] Using cached: cached_pages\www_franchisebazar_com_industry_work-from-home.html
# [('Computer & Internet Franchise', {'Calendaree': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/calendaree', 'Pune, India'], 'Brand Bazooka': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/brand-bazooka', 'Gurgaon, India'], 'Westflix Infotech Software Company': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/westflix-infotech-software-company', 'Gurgaon, India'], 'Netbazzarin': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/netbazzarin', 'Bengaluru, India'], 'TechStoresBN': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/techstoresbn', 'Noida, India'], 'Softcare Application Pvt Ltd': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/softcare-application-pvt-ltd', 'Chengalpattu, India'], 'EASYCARE': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/easycare', 'Dubai, United Arab Emirates'], 'Rax Tech': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/rax-tech', 'Chennai, India'], 'MyPremise': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/mypremise', 'Ranchi, India'], 'Zyple Academy': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/zyple-academy', 'Bengaluru, India'], 'Infograins Software Solutions Pvt Ltd': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/infograins-software-solutions-pvt-ltd', 'Indore, India'], 'Nestack Technologies': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/nestack-technologies-', 'Hyderabad, India'], 'Ravindra': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/ravindra', 'Jodhpur, India'], 'Persistent Edu': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/persistent-edu', 'Bhubaneswar, India'], 'Lappy Maker': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/lappy-maker', 'Delhi, India'], 'NEW ERA INSTITUTE OF COMPUTER SCIENCE': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/new-era-institute-of-computer-science', 'Shupiyan, India'], 'Smartipz Business Solutions': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/smartipz-business-solutions', 'Varkala, India'], 'Edvantage Consultancy Services': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/edvantage-consultancy-services-', 'Patna, India'], 'Interface POS': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/interface-pos', 'Varkala, India'], 'ONLINE HUB': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/online-hub', 'Jagdalpur, India'], 'Dizi Global Solution': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/dizi-global-solution-66199', 'Varanasi, India'], 'Million Pixel': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/million-pixel', 'Nizamabad, India'], 'HUNGRIE': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/hungrie', 'Alandur, India'], 'Star Collection': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/star-collection', 'Mirzapur, India'], 'Deltafox Softwares India Pvt Ltd': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchise-opportunity/deltafox', 'Jabalpur, India'], 'ICollect Softwares': ['https://www.franchisebazar.com//industry/computer-internet-franchise/franchi ...
